# %%
from numpy import *
from numpy.random import *
from PlotFuncs import *
import pandas

# Load all stars
df_shards = pandas.read_csv('../data/FitShards_red.csv')
shard_names = df.group_id.unique()
num_cands = size(names)

# Creating table for latex
nshards = shape(df_shards)[0]
names_str = [None]*nshards
v_str = [None]*nshards
sig_str = [None]*nshards
x_str = [None]*nshards
Psun_str = [None]*nshards
feh_str = [None]*nshards
pop_str = [None]*nshards

vx = df_shards.vx
vy = df_shards.vy
vz = df_shards.vz
sigx = df_shards.sigx
sigy = df_shards.sigy
sigz = df_shards.sigz
x = df_shards.x
y = df_shards.y
z = df_shards.z
feh = df_shards.feh
dfeh = df_shards.dfeh
pops = df_shards.population
Psun = df_shards.Psun

for i in range(0,nshards):
    namei = shard_names[i]
    if namei.endswith('b'):
        names_str[i] = namei
    else:
        names_str[i] = '\hline\hline '+namei
    x_str[i] = '$('+'{:.1f}'.format(x[i])+','+'{:.1f}'.format(y[i])+','+'{:.1f}'.format(z[i])+')$'
    v_str[i] = '$('+'{:.1f}'.format(vx[i])+','+'{:.1f}'.format(vy[i])+','+'{:.1f}'.format(vz[i])+')$'
    sig_str[i] = '$('+'{:.1f}'.format(sigx[i])+','+'{:.1f}'.format(sigy[i])+','+'{:.1f}'.format(sigz[i])+')$'
    feh_str[i] = '$'+'{:.1f}'.format(feh[i])+'\pm '+'{:.1f}'.format(dfeh[i])+'$'
    Psun_str[i] = '{:.1f}'.format(Psun[i])
    pop_str[i] = str(int(pops[i]))
    
    #if namei.endswith('b'):
    #    Psun_str[i] += '\hline'
columnsTitles = ['ID',
                 'No. stars',
                 '$(X,Y,Z)$ [kpc]',
                 '$(v_r,v_\phi,v_z)$',
                 '$(\sigma_r,\sigma_\phi,\sigma_z)$',
                 'Fe/H',
                'P']
df_str = pandas.DataFrame(
    {columnsTitles[0]:names_str,
     columnsTitles[1]:pop_str,
     columnsTitles[2]:x_str,
     columnsTitles[3]:v_str,
    columnsTitles[4]:sig_str,
    columnsTitles[5]:feh_str,
    columnsTitles[6]:Psun_str})
#df_str = pandas.DataFrame([x_str,v_str],columns=['Position','Velocity'])
df_str = df_str.reindex(columns=columnsTitles)
df_str.to_csv('../data/FitShards_text.csv',index=False)

# %%
df_str
# Out:
#                        ID No. stars    $(X,Y,Z)$ [kpc]  \
# 0         \hline\hline S1        32    $(8.6,0.5,2.6)$
# 1        \hline\hline S2a        12    $(9.8,0.2,4.8)$
# 2                     S2b        59    $(8.8,0.3,0.4)$
# 3        \hline\hline Rg2        13    $(8.9,0.3,4.4)$
# 4       \hline\hline Rg5a        14   $(8.1,-0.2,2.2)$
# 5                    Rg5b        15    $(8.4,0.8,1.1)$
# 6       \hline\hline Rg6a        17    $(8.3,0.2,3.3)$
# 7                    Rg6b        12    $(8.5,0.9,3.2)$
# 8       \hline\hline Rg7a         5    $(8.2,0.5,3.3)$
# 9                    Rg7b         9   $(8.9,-0.0,5.1)$
# 10    \hline\hline Cand8a        31   $(9.9,-0.1,2.4)$
# 11                 Cand8b        18    $(8.4,0.6,1.1)$
# 12     \hline\hline Cand9        43   $(9.2,-0.2,1.7)$
# 13    \hline\hline Cand10        38   $(8.6,-0.0,2.0)$
# 14   \hline\hline Cand11a        14   $(9.1,-0.3,2.7)$
# 15                Cand11b        23   $(9.0,-0.1,2.4)$
# 16    \hline\hline Cand12        36   $(9.6,-0.8,3.7)$
# 17    \hline\hline Cand13        36    $(9.1,1.0,3.1)$
# 18   \hline\hline Cand14a        24   $(11.9,0.2,1.8)$
# 19                Cand14b        12   $(10.7,0.3,1.4)$
# 20   \hline\hline Cand15a        12   $(10.5,1.4,4.0)$
# 21                Cand15b         7  $(10.3,-0.3,2.4)$
# 22   \hline\hline Cand16a        12    $(8.7,0.5,3.9)$
# 23                Cand16b         5   $(8.9,2.8,-1.3)$
# 24    \hline\hline Cand17        10   $(9.5,-0.4,2.0)$
# 25    \hline\hline NCand0        19   $(9.4,-0.6,2.4)$
# 26   \hline\hline NCand2a        13   $(9.6,-0.4,3.0)$
# 27                NCand2b        22   $(10.0,0.3,2.3)$
# 28    \hline\hline NCand3         9   $(9.4,0.5,-0.3)$
# 29   \hline\hline NCand6a        11    $(8.1,0.2,1.1)$
# 30                NCand6b        10    $(7.5,1.4,1.7)$
# 31    \hline\hline NCand7        11    $(8.4,1.2,0.7)$
# 32    \hline\hline NCand8         7  $(10.1,-1.3,2.6)$
# 33   \hline\hline NCand9a         9    $(6.9,0.6,2.4)$
# 34                NCand9b        13    $(7.9,0.2,2.3)$
# 35  \hline\hline NCand10a        23   $(9.0,-0.4,1.5)$
# 36               NCand10b        13    $(9.1,0.0,0.9)$
# 37   \hline\hline NCand11        20    $(9.6,0.9,1.5)$
# 38   \hline\hline NCand12        18   $(10.3,0.7,1.7)$
# 39  \hline\hline NCand13a        12    $(7.1,0.2,1.6)$
# 40               NCand13b        17    $(7.4,0.7,1.0)$
# 41   \hline\hline NCand16         5  $(11.1,-0.3,1.9)$
# 42   \hline\hline NCand17        15   $(10.5,0.7,2.7)$
# 43   \hline\hline NCand18        11   $(10.3,0.9,0.3)$
# 44  \hline\hline NCand19a        13   $(9.2,-0.2,0.9)$
# 45               NCand19b        10    $(7.6,0.7,3.9)$
# 46   \hline\hline NCand20         9    $(8.0,0.1,1.8)$
# 47  \hline\hline NCand21a        15    $(9.0,0.2,2.9)$
# 48               NCand21b        11    $(9.2,0.5,2.1)$
# 49   \hline\hline NCand22        20   $(9.7,-0.0,3.3)$
# 50   \hline\hline NCand23         8   $(7.2,-0.1,4.8)$
# 51  \hline\hline NCand24a         7   $(10.0,0.0,1.5)$
# 52               NCand24b         8   $(10.6,0.5,2.1)$
# 53   \hline\hline NCand25         8   $(11.2,1.7,0.9)$
# 54   \hline\hline NCand26         7   $(10.3,1.0,4.0)$
# 55   \hline\hline NCand27        17    $(7.5,0.5,2.4)$
# 56  \hline\hline NCand28a        12    $(9.4,1.1,1.6)$
# 57               NCand28b         8   $(9.0,-0.3,3.4)$
# 58   \hline\hline NCand29        14    $(9.2,0.9,1.2)$
#
#           $(v_r,v_\phi,v_z)$ $(\sigma_r,\sigma_\phi,\sigma_z)$           Fe/H  \
# 0     $(-29.5,-297.2,-73.0)$                $(82.7,26.8,58.5)$  $-1.9\pm 0.3$
# 1      $(-70.9,153.3,161.5)$                $(83.9,29.6,71.5)$  $-2.0\pm 0.3$
# 2       $(6.1,166.8,-242.7)$                $(48.6,13.6,26.1)$  $-1.9\pm 0.2$
# 3      $(44.5,-248.4,185.2)$               $(105.9,23.1,63.5)$  $-1.6\pm 0.2$
# 4      $(-37.8,-83.8,179.3)$                $(47.2,16.8,31.2)$  $-2.1\pm 0.3$
# 5       $(6.3,-74.6,-159.5)$                $(32.3,17.5,31.8)$  $-2.2\pm 0.3$
# 6     $(105.1,-230.2,202.4)$                $(73.7,16.8,86.6)$  $-1.6\pm 0.2$
# 7     $(-233.2,-221.8,51.6)$               $(32.7,14.4,115.7)$  $-1.7\pm 0.3$
# 8     $(309.0,-191.3,-83.4)$               $(66.7,17.1,102.7)$  $-1.5\pm 0.1$
# 9   $(-288.7,-158.1,-105.5)$               $(78.7,65.8,111.8)$  $-1.5\pm 0.3$
# 10     $(-6.7,207.7,-186.4)$               $(114.6,20.8,73.5)$  $-1.8\pm 0.4$
# 11      $(33.6,213.9,214.1)$                $(96.5,22.7,37.7)$  $-1.8\pm 0.2$
# 12     $(11.0,177.5,-251.4)$              $(120.6,13.9,132.2)$  $-1.8\pm 0.2$
# 13      $(-37.4,20.0,192.3)$              $(161.5,18.2,195.0)$  $-2.0\pm 0.2$
# 14     $(36.8,116.5,-271.5)$                $(96.1,27.9,95.4)$  $-2.1\pm 0.3$
# 15     $(-152.7,80.2,258.2)$               $(122.1,21.0,38.9)$  $-2.0\pm 0.3$
# 16      $(-43.3,102.4,50.0)$              $(172.8,21.2,197.8)$  $-1.6\pm 0.2$
# 17      $(-2.1,-13.2,202.2)$              $(215.7,28.1,215.9)$  $-1.4\pm 0.2$
# 18    $(-168.0,166.7,-25.1)$                $(29.1,27.9,82.7)$  $-1.4\pm 0.2$
# 19      $(193.5,202.9,-5.8)$                $(14.2,13.7,52.8)$  $-1.5\pm 0.1$
# 20    $(-297.4,220.0,-49.9)$                $(29.6,23.5,79.3)$  $-1.5\pm 0.1$
# 21      $(291.3,207.3,48.3)$                $(20.2,10.4,68.7)$  $-1.4\pm 0.1$
# 22     $(315.2,109.2,-12.5)$                 $(30.9,4.6,67.2)$  $-1.4\pm 0.2$
# 23     $(-360.7,147.5,81.7)$                 $(26.7,9.2,76.3)$  $-1.4\pm 0.1$
# 24      $(127.6,68.0,339.4)$                $(157.4,8.0,54.8)$  $-2.1\pm 0.2$
# 25       $(364.6,94.2,56.3)$                $(27.2,15.7,41.1)$  $-1.4\pm 0.2$
# 26       $(270.2,133.8,4.8)$               $(59.5,14.3,163.4)$  $-1.6\pm 0.2$
# 27    $(-250.8,139.5,-28.1)$               $(69.6,14.9,160.7)$  $-1.6\pm 0.2$
# 28    $(-212.9,104.5,123.8)$                $(30.8,8.0,192.7)$  $-1.4\pm 0.1$
# 29     $(-11.9,-32.9,177.6)$                 $(30.0,13.5,7.2)$  $-2.0\pm 0.1$
# 30     $(-3.6,-30.4,-180.5)$                $(30.2,11.4,10.8)$  $-2.0\pm 0.3$
# 31  $(-178.5,-114.8,-107.3)$              $(188.3,14.6,302.6)$  $-1.3\pm 0.3$
# 32      $(26.2,375.0,-34.1)$                $(47.9,12.8,85.4)$  $-1.8\pm 0.2$
# 33      $(-0.8,64.9,-189.3)$                $(24.1,13.9,20.9)$  $-1.8\pm 0.4$
# 34      $(-12.2,66.8,190.6)$                $(29.7,16.4,28.1)$  $-2.1\pm 0.3$
# 35      $(-21.9,34.2,233.1)$                $(61.7,16.8,43.9)$  $-1.9\pm 0.3$
# 36      $(-1.5,23.9,-186.2)$                $(60.8,19.8,41.7)$  $-1.8\pm 0.4$
# 37      $(-8.5,-212.9,98.8)$                $(72.3,21.1,89.5)$  $-1.8\pm 0.1$
# 38      $(1.9,128.2,-152.3)$              $(137.9,12.7,126.9)$  $-1.7\pm 0.3$
# 39       $(7.9,144.6,141.2)$                $(35.7,17.2,24.6)$  $-1.7\pm 0.4$
# 40     $(-0.1,163.6,-137.5)$                $(25.4,12.7,15.4)$  $-1.7\pm 0.3$
# 41       $(-75.1,-5.0,62.7)$                $(92.3,6.6,227.0)$  $-1.9\pm 0.5$
# 42       $(1.5,224.8,-18.9)$                $(86.3,29.0,95.5)$  $-1.7\pm 0.2$
# 43     $(71.0,-84.6,-338.4)$                $(45.7,16.4,29.6)$  $-2.2\pm 0.2$
# 44    $(-11.9,-147.8,176.3)$                $(51.3,17.1,24.1)$  $-2.0\pm 0.2$
# 45     $(-1.2,-135.2,-99.6)$                 $(39.2,9.6,45.4)$  $-1.8\pm 0.2$
# 46    $(-34.7,-145.3,-92.9)$                $(27.2,14.2,39.5)$  $-2.0\pm 0.2$
# 47     $(-6.5,-117.2,226.9)$                $(65.2,12.6,34.0)$  $-1.7\pm 0.3$
# 48   $(-26.0,-113.5,-243.7)$                $(59.0,10.6,23.3)$  $-1.9\pm 0.2$
# 49    $(-19.3,-174.6,-44.4)$               $(95.5,17.0,127.2)$  $-1.9\pm 0.2$
# 50     $(-450.2,-25.4,78.9)$                $(22.4,12.9,27.9)$  $-1.4\pm 0.1$
# 51     $(-80.8,253.9,-78.9)$                $(30.5,14.9,29.9)$  $-1.8\pm 0.2$
# 52       $(120.3,269.2,1.6)$                $(23.2,18.2,43.3)$  $-1.8\pm 0.3$
# 53     $(-95.0,199.4,-20.1)$                $(87.1,17.8,84.7)$  $-1.4\pm 0.1$
# 54       $(9.2,212.6,183.7)$                $(78.1,11.7,29.4)$  $-1.5\pm 0.3$
# 55    $(-18.0,-108.3,-54.5)$               $(40.7,22.2,123.9)$  $-2.0\pm 0.2$
# 56     $(-299.4,28.1,-10.2)$                 $(25.9,5.2,61.5)$  $-1.4\pm 0.3$
# 57      $(249.5,19.5,115.5)$                $(67.6,7.6,118.8)$  $-1.3\pm 0.1$
# 58   $(-73.0,-325.6,-113.6)$               $(166.5,27.8,92.3)$  $-1.8\pm 0.5$
#
#       P
# 0   1.0
# 1   1.5
# 2   0.4
# 3   1.4
# 4   0.9
# 5   0.7
# 6   1.1
# 7   0.6
# 8   1.1
# 9   1.8
# 10  0.4
# 11  0.1
# 12  0.5
# 13  0.2
# 14  0.3
# 15  0.5
# 16  0.6
# 17  0.4
# 18  1.2
# 19  0.7
# 20  1.2
# 21  0.5
# 22  0.7
# 23  0.9
# 24  0.7
# 25  0.5
# 26  0.9
# 27  0.6
# 28  0.8
# 29  0.2
# 30  0.6
# 31  0.8
# 32  1.0
# 33  0.9
# 34  0.2
# 35  0.1
# 36  0.2
# 37  0.4
# 38  0.4
# 39  0.7
# 40  1.1
# 41  0.5
# 42  1.4
# 43  0.6
# 44  0.6
# 45  1.1
# 46  0.1
# 47  0.3
# 48  0.4
# 49  0.3
# 50  1.0
# 51  0.5
# 52  0.8
# 53  1.8
# 54  0.5
# 55  0.3
# 56  0.8
# 57  1.7
# 58  0.7
