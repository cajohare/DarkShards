# %%
from numpy import *
import matplotlib.pyplot as plt
from LabFuncs import *
from Params import *
from HaloFuncs import *
from WIMPFuncs import *

v_min = linspace(0.1,800.0,100)
day = 0

g2 = gvmin_Isotropic(v_min,day)
g1 = gvmin_Triaxial(v_min,day,164.75*array([1.0,1.0,2.0]))
                    
plt.plot(v_min,g1)
plt.plot(v_min,g2,'--')
plt.yscale('log')
plt.show()
